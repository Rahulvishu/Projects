# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from pandas import ExcelWriter
from pandas import ExcelFile
df=pd.read_excel('hr_analytics.xlsx')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
df["Attrition"].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
df['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
df['OverTime'].value_counts()
# Out:
# No     1054
# Yes     416
# Name: OverTime, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     673
# Single      470
# Divorced    327
# Name: MaritalStatus, dtype: int64

# %%
df['JobRole'].value_counts()
# Out:
# Sales Executive              326
# Research Scientist           292
# Laboratory Technician        259
# Manufacturing Director       145
# Healthcare Representative    131
# Manager                      102
# Sales Representative          83
# Research Director             80
# Human Resources               52
# Name: JobRole, dtype: int64

# %%
df['EducationField'].value_counts()
# Out:
# Life Sciences       606
# Medical             464
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: EducationField, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      882
# Female    588
# Name: Gender, dtype: int64

# %%
df.isnull().sum()    #no null values presnt in the dataset
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["Attrition"]=le.fit_transform(df["Attrition"])
df['BusinessTravel']=le.fit_transform(df['BusinessTravel'])
df['Gender']=le.fit_transform(df['Gender'])
df['EducationField']=le.fit_transform(df['EducationField'])
df['JobRole']=le.fit_transform(df['JobRole'])
df['Over18']=le.fit_transform(df['Over18'])
df['OverTime']=le.fit_transform(df['OverTime'])
df['Department']=le.fit_transform(df['Department'])
df['MaritalStatus']=le.fit_transform(df['MaritalStatus'])

# %%
df['Attrition'].value_counts()    #we have changed categorical value into int type
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
df.dtypes
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeCount               int64
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# Over18                      int32
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StandardHours               int64
# ...

# %%
df.describe()
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1470.000000  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810     0.161224        1.607483   802.485714     1.260544
# std       9.135373     0.367863        0.665455   403.509100     0.527792
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   465.000000     1.000000
# 50%      36.000000     0.000000        2.000000   802.000000     1.000000
# 75%      43.000000     0.000000        2.000000  1157.000000     2.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       1470.000000  1470.000000     1470.000000         1470.0
# mean           9.192517     2.912925        2.247619            1.0
# std            8.106864     1.024165        1.331369            0.0
# ...

# %%
df.corr()['Attrition'].sort_values()   # we see that Employee count,over 18,standard hours are not in correlation with the target variable
# Out:
# TotalWorkingYears          -0.171063
# JobLevel                   -0.169105
# YearsInCurrentRole         -0.160545
# MonthlyIncome              -0.159840
# Age                        -0.159205
# YearsWithCurrManager       -0.156199
# StockOptionLevel           -0.137145
# YearsAtCompany             -0.134392
# JobInvolvement             -0.130016
# JobSatisfaction            -0.103481
# EnvironmentSatisfaction    -0.103369
# WorkLifeBalance            -0.063939
# TrainingTimesLastYear      -0.059478
# DailyRate                  -0.056652
# RelationshipSatisfaction   -0.045872
# YearsSinceLastPromotion    -0.033019
# Education                  -0.031373
# PercentSalaryHike          -0.013478
# EmployeeNumber             -0.010577
# HourlyRate                 -0.006846
# BusinessTravel              0.000074
# PerformanceRating           0.002889
# MonthlyRate                 0.015170
# EducationField              0.026846
# Gender                      0.029453
# ...

# %%
df=df.drop(['EmployeeCount','Over18','StandardHours'],axis=1)  #we have dropped three columns based on the above observation

# %%
df.shape
# Out:
# (1470, 32)

# %%
sns.scatterplot(x='OverTime',y="Attrition",data=df)  #we are not able to find out from these graphs
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='Attrition'>

# %%
 sns.scatterplot(x='MonthlyRate',y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='MonthlyRate', ylabel='Attrition'>

# %%
sns.scatterplot(x='PerformanceRating',y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='Attrition'>

# %%
sns.scatterplot(x='Department',y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='Attrition'>

# %%
sns.scatterplot(x='WorkLifeBalance',y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='WorkLifeBalance', ylabel='Attrition'>

# %%
sns.scatterplot(x='NumCompaniesWorked',y="Attrition",data=df)
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Attrition'>

# %%
plt.figure(figsize=[20,15])
sns.heatmap(df.corr(),annot=True,fmt='.2f')      # we find few columns with possitive correlation and most other columns are negatively correlated
plt.title('Correalation Matrix')
plt.show()

# %% [markdown]
# To check skewness in the data

# %%
df.skew()
# Out:
# Age                         0.413286
# Attrition                   1.844366
# BusinessTravel             -1.439006
# DailyRate                  -0.003519
# Department                  0.172231
# DistanceFromHome            0.958118
# Education                  -0.289681
# EducationField              0.550371
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# Gender                     -0.408665
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# MaritalStatus              -0.152175
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# OverTime                    0.964489
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StockOptionLevel            0.968980
# ...

# %%
sns.distplot(df['NumCompaniesWorked'])
# Out:
# <AxesSubplot:xlabel='NumCompaniesWorked', ylabel='Density'>

# %%
sns.distplot(df['YearsSinceLastPromotion'])
# Out:
# <AxesSubplot:xlabel='YearsSinceLastPromotion', ylabel='Density'>

# %%
sns.distplot(df['BusinessTravel'])
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='Density'>

# %%
df.plot(kind='kde',subplots=True,layout=(5,7),figsize=(20,15))    #skewness is present in few columns
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %% [markdown]
# Checking  outliers

# %%
df.plot(kind='box',subplots=True,layout=(5,7),figsize=(20,15))
# Out:
# Age                            AxesSubplot(0.125,0.749828;0.0945122x0.130172)
# Attrition                   AxesSubplot(0.238415,0.749828;0.0945122x0.130172)
# BusinessTravel              AxesSubplot(0.351829,0.749828;0.0945122x0.130172)
# DailyRate                   AxesSubplot(0.465244,0.749828;0.0945122x0.130172)
# Department                  AxesSubplot(0.578659,0.749828;0.0945122x0.130172)
# DistanceFromHome            AxesSubplot(0.692073,0.749828;0.0945122x0.130172)
# Education                   AxesSubplot(0.805488,0.749828;0.0945122x0.130172)
# EducationField                 AxesSubplot(0.125,0.593621;0.0945122x0.130172)
# EmployeeNumber              AxesSubplot(0.238415,0.593621;0.0945122x0.130172)
# EnvironmentSatisfaction     AxesSubplot(0.351829,0.593621;0.0945122x0.130172)
# Gender                      AxesSubplot(0.465244,0.593621;0.0945122x0.130172)
# HourlyRate                  AxesSubplot(0.578659,0.593621;0.0945122x0.130172)
# ...

# %%
# we find outliers present in few of the columns

# %% [markdown]
# Removing Outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z.shape
# Out:
# (1470, 32)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  28,   45,   62,   62,   63,   64,   85,   98,   98,  110,  123,
#         123,  123,  126,  126,  126,  153,  178,  187,  187,  190,  190,
#         218,  231,  231,  237,  237,  270,  270,  281,  326,  386,  386,
#         401,  411,  425,  425,  427,  445,  466,  473,  477,  535,  561,
#         561,  584,  592,  595,  595,  595,  616,  624,  635,  653,  653,
#         677,  686,  701,  716,  746,  749,  752,  799,  838,  861,  861,
#         875,  875,  894,  914,  914,  918,  922,  926,  926,  937,  956,
#         962,  976,  976, 1008, 1024, 1043, 1078, 1078, 1086, 1086, 1093,
#        1111, 1116, 1116, 1135, 1138, 1138, 1156, 1184, 1221, 1223, 1242,
#        1295, 1301, 1301, 1303, 1327, 1331, 1348, 1351, 1401, 1414, 1430],
#       dtype=int64), array([31, 30, 28, 30, 29, 30, 25, 25, 28, 30, 29, 30, 31, 25, 28, 30, 31,
#        30, 25, 31, 28, 29, 30, 29, 31, 28, 30, 25, 28, 29, 30, 30, 31, 25,
# ...

# %%
len(np.where(z>3)[0])
# Out:
# 110

# %%
df_new=df[(z<3).all(axis=1)]
print('old shape',df.shape)
print('New shape',df_new.shape)
# Out:
# old shape (1470, 32)
# New shape (1387, 32)

# %%
loss_data=(1470-1387)/1470*100     #less percentage of loss of data
print('perentage of loss',loss_data)
# Out:
# perentage of loss 5.646258503401361

# %%
x=df_new.drop('Attrition',axis=1)  #SPLITTING OF DATA
y=df_new["Attrition"]

# %%
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1387, dtype: int32

# %%
from sklearn.preprocessing import power_transform     #to remove skewness in the data
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 0.61013332,  0.63872976,  0.75061538, ...,  0.29052433,
#         -1.07353381,  0.58217664],
#        [ 1.37182974, -1.38077628, -1.34337244, ...,  1.0065754 ,
#          0.19316755,  1.01807316],
#        [ 0.18248603,  0.63872976,  1.33708042, ..., -1.57181404,
#         -1.07353381, -1.52842596],
#        ...,
#        [-1.0804891 ,  0.63872976, -1.75453754, ..., -0.39076907,
#         -1.07353381,  0.01867962],
#        [ 1.37182974, -1.38077628,  0.57328582, ...,  0.79376377,
#         -1.07353381,  1.20578193],
#        [-0.16377603,  0.63872976, -0.37222758, ..., -0.01873824,
#          0.19316755, -0.3478709 ]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.61013332,  0.63872976,  0.75061538, ...,  0.29052433,
#         -1.07353381,  0.58217664],
#        [ 1.37182974, -1.38077628, -1.34337244, ...,  1.0065754 ,
#          0.19316755,  1.01807316],
#        [ 0.18248603,  0.63872976,  1.33708042, ..., -1.57181404,
#         -1.07353381, -1.52842596],
#        ...,
#        [-1.0804891 ,  0.63872976, -1.75453754, ..., -0.39076907,
#         -1.07353381,  0.01867962],
#        [ 1.37182974, -1.38077628,  0.57328582, ...,  0.79376377,
#         -1.07353381,  1.20578193],
#        [-0.16377603,  0.63872976, -0.37222758, ..., -0.01873824,
#          0.19316755, -0.3478709 ]])

# %%
Looking at the target variable we can perform Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random_state:',i)
        print('Training accuracy_score',accuracy_score(y_train,pred_train)*100)
        print('testing accuracy_score',accuracy_score(y_test,pred_test)*100,'\n\n')
# Out:
# At random_state: 159
# Training accuracy_score 88.09738503155997
# testing accuracy_score 88.12949640287769
#
#
# At random_state: 193
# Training accuracy_score 88.5482416591524
# testing accuracy_score 88.48920863309353
#
#
# At random_state: 196
# Training accuracy_score 87.8268710550045
# testing accuracy_score 87.76978417266187
#
#
# At random_state: 245
# Training accuracy_score 88.09738503155997
# testing accuracy_score 88.12949640287769
#
#
# At random_state: 279
# Training accuracy_score 88.5482416591524
# testing accuracy_score 88.48920863309353
#
#
# At random_state: 312
# Training accuracy_score 88.45807033363391
# testing accuracy_score 88.48920863309353
#
#
# At random_state: 385
# Training accuracy_score 88.09738503155997
# testing accuracy_score 88.12949640287769
#
#
# At random_state: 496
# Training accuracy_score 88.09738503155997
# testing accuracy_score 88.12949640287769
#
#
# At random_state: 616
# Training accuracy_score 87.8268710550045
# ...

# %%
# at random state 883 the training and testing accuracy is same

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=883,test_size=.20)
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       237
#            1       0.03      0.02      0.03        41
#
#     accuracy                           0.74       278
#    macro avg       0.43      0.45      0.44       278
# weighted avg       0.72      0.74      0.73       278

# %%
# we are getting the f1score of 85%

# %% [markdown]
# Performing PCA for the above data to remove colinear columns

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=None)
pca.fit(x)

                                                                 # Get the eigenvalues
print("Eigenvalues:")
print(pca.explained_variance_)
print()

                                                                  # Get explained variances
print("Variances (Percentage):")
print(pca.explained_variance_ratio_ * 100)
print()

                                                                   # Make the scree plot
plt.plot(np.cumsum(pca.explained_variance_ratio_ * 100))
plt.xlabel("Number of components (Dimensions)")
plt.ylabel("Explained variance (%)")
# Out:
# Eigenvalues:
# [4.29398831e+00 2.14438618e+00 1.81549110e+00 1.66851913e+00
#  1.19976219e+00 1.15382534e+00 1.13357420e+00 1.10474256e+00
#  1.09203393e+00 1.05491958e+00 1.03624375e+00 1.01900094e+00
#  9.89910423e-01 9.67037052e-01 9.63307046e-01 9.29473705e-01
#  9.03304633e-01 8.89401633e-01 8.74695024e-01 8.44156884e-01
#  8.32376360e-01 7.63195833e-01 6.13001595e-01 5.41451333e-01
#  2.84668524e-01 2.65748042e-01 2.45937467e-01 1.93485095e-01
#  1.10163598e-01 9.38435640e-02 2.09259481e-32]
#
# Variances (Percentage):
# [1.43029748e+01 7.14280039e+00 6.04727389e+00 5.55772054e+00
#  3.99632395e+00 3.84331153e+00 3.77585638e+00 3.67982022e+00
#  3.63748863e+00 3.51386335e+00 3.45165546e+00 3.39422087e+00
#  3.29732239e+00 3.22113279e+00 3.20870840e+00 3.09601191e+00
#  3.00884456e+00 2.96253464e+00 2.91354795e+00 2.81182754e+00
#  2.77258744e+00 2.54215194e+00 2.04186544e+00 1.80353652e+00
#  9.48210945e-01 8.85188144e-01 8.19200503e-01 6.44485321e-01
# ...

# %%
# we can take no.of componenets= 20 where the number of columns will be reduced to 20 on applying PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=20)
X_pca = pca.fit_transform(x)

                                   # Get the transformed dataset
X = pd.DataFrame(X_pca)
print(X.head())
print("\nSize: ")
print(X.shape)
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.422736  0.538018 -2.413930 -0.037326  2.916555 -1.007669 -0.887708
# 1 -1.476821 -0.832240  0.361157  0.249610  0.780943  0.562060  1.330647
# 2  3.485575  1.685685 -0.449960  1.415983  1.571419  1.443476 -0.850610
# 3  0.485217 -1.030011 -0.284822  0.605918  2.160385  1.189674 -0.444229
# 4  1.553593  0.207987  0.948550  0.762911  0.283353  0.941023  0.200008
#
#          7         8         9         10        11        12        13  \
# 0 -0.510863  1.697724 -2.479588 -2.590688 -1.079753 -0.004858 -1.258023
# 1 -0.773198 -0.775997  2.385209 -0.301498 -0.946103  2.243623  0.200159
# 2  2.789331  0.767398 -1.358239  0.762625 -0.725503  0.741672 -0.678859
# 3 -0.540938 -1.247472 -0.598182 -1.805671  2.379221  0.155270 -0.335220
# 4  1.692494 -1.021700  1.087522 -1.463657 -1.520855  0.442396  1.411739
#
#          14        15        16        17        18        19
# ...

# %%
#model training after PCA

# %%
for i in range(0,1000):
    X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=i,test_size=0.20)
    lr.fit(X_train,y_train)
    pred_train=lr.predict(X_train)
    pred_test=lr.predict(X_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print('At random_state:',i)
        print('Training accuracy_score',accuracy_score(y_train,pred_train)*100)
        print('testing accuracy_score',accuracy_score(y_test,pred_test)*100,'\n\n')
# Out:
# At random_state: 11
# Training accuracy_score 86.6546438232642
# testing accuracy_score 86.6906474820144
#
#
# At random_state: 39
# Training accuracy_score 86.02344454463481
# testing accuracy_score 85.97122302158273
#
#
# At random_state: 80
# Training accuracy_score 86.6546438232642
# testing accuracy_score 86.6906474820144
#
#
# At random_state: 158
# Training accuracy_score 86.29395852119026
# testing accuracy_score 86.33093525179856
#
#
# At random_state: 312
# Training accuracy_score 86.74481514878268
# testing accuracy_score 86.6906474820144
#
#
# At random_state: 446
# Training accuracy_score 86.74481514878268
# testing accuracy_score 86.6906474820144
#
#
# At random_state: 648
# Training accuracy_score 86.02344454463481
# testing accuracy_score 85.97122302158273
#
#
# At random_state: 737
# Training accuracy_score 86.74481514878268
# testing accuracy_score 86.6906474820144
#
#
# At random_state: 746
# Training accuracy_score 86.29395852119026
# ...

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=312,test_size=.20)
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89       231
#            1       0.35      0.13      0.19        47
#
#     accuracy                           0.81       278
#    macro avg       0.60      0.54      0.54       278
# weighted avg       0.76      0.81      0.77       278

# %%
#we found f1score=89% after PCA step

# %% [markdown]
# Cross Validation

# %%
from sklearn.model_selection import cross_val_score
lss=accuracy_score(y_test,pred_test)

# %%
for j in range(2,10):
    lsscore= cross_val_score(lr,X,y,cv=j)
    lsc= lsscore.mean()
    print('at cv=',j)
    print('cross validation score is',lsc *100)
    print('accuracy_score is',lss*100)
    print('\n')
# Out:
# at cv= 2
# cross validation score is 85.21994336115372
# accuracy_score is 81.29496402877699
#
#
# at cv= 3
# cross validation score is 85.36397607671906
# accuracy_score is 81.29496402877699
#
#
# at cv= 4
# cross validation score is 85.94184671253187
# accuracy_score is 81.29496402877699
#
#
# at cv= 5
# cross validation score is 86.08653871126926
# accuracy_score is 81.29496402877699
#
#
# at cv= 6
# cross validation score is 85.94099865651589
# accuracy_score is 81.29496402877699
#
#
# at cv= 7
# cross validation score is 86.30163806043203
# accuracy_score is 81.29496402877699
#
#
# at cv= 8
# cross validation score is 86.01421832436382
# accuracy_score is 81.29496402877699
#
#
# at cv= 9
# cross validation score is 86.08481124610157
# accuracy_score is 81.29496402877699

# %% [markdown]
# Trying with different models

# %%
import sklearn
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import  KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

knn=KNeighborsClassifier() 
gnb=GaussianNB()
svc=SVC()
dtc=DecisionTreeClassifier()


model=[gnb,svc,dtc,knn]

for m in model:
    m.fit(X_train,y_train)
    m.score(X_test,y_test)
    predm=m.predict(X_test)
    print ('accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# accuracy score of GaussianNB() is:
# 0.8489208633093526
# [[229   2]
#  [ 40   7]]
#               precision    recall  f1-score   support
#
#            0       0.85      0.99      0.92       231
#            1       0.78      0.15      0.25        47
#
#     accuracy                           0.85       278
#    macro avg       0.81      0.57      0.58       278
# weighted avg       0.84      0.85      0.80       278
#
#
#
# accuracy score of SVC() is:
# 0.8489208633093526
# [[230   1]
#  [ 41   6]]
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92       231
#            1       0.86      0.13      0.22        47
#
#     accuracy                           0.85       278
#    macro avg       0.85      0.56      0.57       278
# weighted avg       0.85      0.85      0.80       278
#
#
#
# accuracy score of DecisionTreeClassifier() is:
# 0.7482014388489209
# [[194  37]
#  [ 33  14]]
# ...

# %%
# we find the K neighbour classifer is providing f1score 0f 91%  we would choose this model

# %%
#cross validation for Kneighbour classifier
for j in range(2,10):
    lsscore= cross_val_score(knn,X,y,cv=j)
    lsc= lsscore.mean()
    print('at cv=',j)
    print('cross validation score is',lsc *100)
    print('accuracy_score is',lss*100)
    print('\n')
# Out:
# at cv= 2
# cross validation score is 84.13862794266251
# accuracy_score is 81.29496402877699
#
#
# at cv= 3
# cross validation score is 84.13789234523576
# accuracy_score is 81.29496402877699
#
#
# at cv= 4
# cross validation score is 83.56182638969865
# accuracy_score is 81.29496402877699
#
#
# at cv= 5
# cross validation score is 83.63400254525622
# accuracy_score is 81.29496402877699
#
#
# at cv= 6
# cross validation score is 83.8505125143056
# accuracy_score is 81.29496402877699
#
#
# at cv= 7
# cross validation score is 83.56174813461247
# accuracy_score is 81.29496402877699
#
#
# at cv= 8
# cross validation score is 84.4275297322437
# accuracy_score is 81.29496402877699
#
#
# at cv= 9
# cross validation score is 84.21030582320905
# accuracy_score is 81.29496402877699

# %%
#Hyper prameter tuning

from sklearn.model_selection import GridSearchCV   #Grid Search CV
leaf_size = list(range(1,50))
n_neighbors = list(range(1,30))
p=[1,2]
hyperparameters = dict(leaf_size=leaf_size, n_neighbors=n_neighbors, p=p)
knn_2 = KNeighborsClassifier()
clf = GridSearchCV(knn_2, hyperparameters, cv=8)
best_model = clf.fit(X,y)
print('Best leaf_size:', best_model.best_estimator_.get_params()['leaf_size'])
print('Best p:', best_model.best_estimator_.get_params()['p'])
print('Best n_neighbors:', best_model.best_estimator_.get_params()['n_neighbors'])
# Out:
# Best leaf_size: 1
# Best p: 2
# Best n_neighbors: 5

# %%
 GCV_pred=clf.best_estimator_.predict(X_test)
accuracy_score(y_test,GCV_pred)
# Out:
# 0.8776978417266187

# %%
from sklearn.metrics import plot_roc_curve
plot_roc_curve(clf.best_estimator_,X_test,y_test)
plt.title('ROC AUC plot')
plt.show()

# %%
# we see the AUC plot shows the model is working 90% accuracy to distinguish between Attrition

# %%
import joblib
joblib.dump(clf.best_estimator_,'hr_analytics.pkl')
# Out:
# ['hr_analytics.pkl']
